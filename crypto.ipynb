# %%
# https://medium.com/@nafisaidris413/how-i-traced-a-cryptocurrency-transaction-blockchain-analysis-and-fund-tracing-with-python-cc04375f2e06#id_token=eyJhbGciOiJSUzI1NiIsImtpZCI6IjE3ZjBmMGYxNGU5Y2FmYTlhYjUxODAxNTBhZTcxNGM5ZmQxYjVjMjYiLCJ0eXAiOiJKV1QifQ.....MtrsXD5vJVcvmtk5h7NR2FWFpmtEUelKyMA5rLKh_bfYCfBfoJx-b1KcJwoX3fv9oMbSIFhsjTZ0qp0OSld1Pwk7Q5vNdflClx2AxyuMBAxLmUX-WvnnKerlX9-bIX_YSL4jFHPl4BqzyfUUoSfgb4eWIyp0TIOds1A8egx4neD4R4V-zIhJK_WU0lGafGGB6XZPDWGt6X9J9bdumpC-A0tdFEC6au9hTlEe3yJFZNxGu28tPX7T4S970dsPBRXQMYiHKiykQYUYx9jwg0uEe8HPzae0-owPyyOEVXPUDWDq4v4hfKP4AA_qzRFvktKHWg4-2pmDZsFg7Fbjh2f6pQ

# pip install requests beautifulsoup4 python-dotenv web3 matplotlib whois  fpdf2 networkx

# %%
import os
import logging
from datetime import datetime
from requests.exceptions import RequestException
from bs4 import BeautifulSoup
import whois
from web3 import Web3
import json
from fpdf import FPDF
import matplotlib.pyplot as plt
import networkx as nx
from dotenv import load_dotenv
import requests
