# %%
import pandas as pd

# %%
counts = {"count": [2221, 125, 29, 2 ]}

# %%
num_visas = {"num_visas": [1, 2, 3, 4 ]}

# %%
data = {"num_visas": [1, 2, 3, 4 ], "count": [2221, 125, 29, 2 ] }

# %%
df = pd.DataFrame(data)
df
# Out:
#    num_visas  count
# 0          1   2221
# 1          2    125
# 2          3     29
# 3          4      2

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
num_visas = [1, 2, 3, 4 ]
count =  [2221, 125, 29, 2 ]

# %%
df2 = pd.DataFrame({'count':count }, index=num_visas)
df2.index.name = 'Num Visas per record'
df2
# Out:
#                       count
# Num Visas per record
# 1                      2221
# 2                       125
# 3                        29
# 4                         2

# %%
df2.plot.bar()
# Out:
# <Axes: xlabel='Num Visas per record'>
